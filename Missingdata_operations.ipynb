# %%
import pandas as pd
baseball=pd.read_csv(r'Files\baseball.csv')
baseball.head(5)
# Out:
#    Unnamed: 0  Rk  Year                    Tm       Lg    G   W   L  Ties  \
# 0           1   1  2016  Arizona Diamondbacks  NL West  162  69  93     0
# 1           2   2  2015  Arizona Diamondbacks  NL West  162  79  83     0
# 2           3   3  2014  Arizona Diamondbacks  NL West  162  64  98     0
# 3           4   4  2013  Arizona Diamondbacks  NL West  162  81  81     0
# 4           5   5  2012  Arizona Diamondbacks  NL West  162  81  81     0
#
#     W.L.          ...             R   RA Attendance BatAge  PAge  X.Bat X.P  \
# 0  0.426          ...           752  890  2,036,216   26.7  26.4     50  29
# 1  0.488          ...           720  713  2,080,145   26.6  27.1     50  27
# 2  0.395          ...           615  742  2,073,730   27.6  28.0     52  25
# 3  0.500          ...           685  695  2,134,895   28.1  27.6     44  23
# 4  0.500          ...           734  688  2,177,617   28.3  27.4     48  23
#
# ...

# %%
baseball.describe()
# Out:
#         Unnamed: 0           Rk         Year            G            W  \
# count  2594.000000  2594.000000  2594.000000  2594.000000  2594.000000
# mean   1297.500000    54.824981  1962.175019   155.188897    77.513878
# std     748.967623    37.413876    37.413876    12.548301    14.054629
# min       1.000000     1.000000  1876.000000    60.000000    17.000000
# 25%     649.250000    22.000000  1931.000000   154.000000    68.000000
# 50%    1297.500000    48.000000  1969.000000   161.000000    78.000000
# 75%    1945.750000    86.000000  1995.000000   162.000000    88.000000
# max    2594.000000   141.000000  2016.000000   165.000000   116.000000
#
#                  L         Ties         W.L.     pythW.L.            R  \
# count  2594.000000  2594.000000  2594.000000  2594.000000  2594.000000
# mean     76.925983     0.749036     0.502478     0.502547   694.480339
# std      14.629448     1.299325     0.084522     0.079307   113.883503
# ...

# %%
baseball.info()
#for missing data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2594 entries, 0 to 2593
# Data columns (total 24 columns):
# Unnamed: 0    2594 non-null int64
# Rk            2594 non-null int64
# Year          2594 non-null int64
# Tm            2594 non-null object
# Lg            2594 non-null object
# G             2594 non-null int64
# W             2594 non-null int64
# L             2594 non-null int64
# Ties          2594 non-null int64
# W.L.          2594 non-null float64
# pythW.L.      2594 non-null float64
# Finish        2594 non-null object
# GB            2594 non-null object
# Playoffs      431 non-null object
# R             2594 non-null int64
# RA            2594 non-null int64
# Attendance    2520 non-null object
# BatAge        2594 non-null float64
# PAge          2594 non-null float64
# X.Bat         2594 non-null int64
# X.P           2594 non-null int64
# Top.Player    2594 non-null object
# Managers      2594 non-null object
# current       2594 non-null object
# ...

# %%
df=baseball
df.isnull().sum()
#missing data
# Out:
# Unnamed: 0       0
# Rk               0
# Year             0
# Tm               0
# Lg               0
# G                0
# W                0
# L                0
# Ties             0
# W.L.             0
# pythW.L.         0
# Finish           0
# GB               0
# Playoffs      2163
# R                0
# RA               0
# Attendance      74
# BatAge           0
# PAge             0
# X.Bat            0
# X.P              0
# Top.Player       0
# Managers         0
# current          0
# dtype: int64

# %%
df.shape
# Out:
# (2594, 24)

# %%
df['Tm'].value_counts()
# Out:
# Philadelphia Phillies            127
# Pittsburgh Pirates               126
# Cincinnati Reds                  121
# St. Louis Cardinals              117
# Chicago White Sox                116
# Detroit Tigers                   116
# Chicago Cubs                     114
# Boston Red Sox                   109
# New York Yankees                 104
# Cleveland Indians                102
# New York Giants                   73
# Washington Senators               71
# St. Louis Browns                  68
# Baltimore Orioles                 63
# Los Angeles Dodgers               59
# San Francisco Giants              59
# Minnesota Twins                   56
# New York Mets                     55
# Philadelphia Athletics            54
# Houston Astros                    52
# Atlanta Braves                    51
# Oakland Athletics                 49
# San Diego Padres                  48
# Milwaukee Brewers                 48
# Kansas City Royals                48
# ...

# %%
df['Tm'].value_counts().head(3)
#Top 3 Teams
# Out:
# Philadelphia Phillies    127
# Pittsburgh Pirates       126
# Cincinnati Reds          121
# Name: Tm, dtype: int64

# %%
df['Tm'].value_counts().tail(3)
# Out:
# Cleveland Bronchos           1
# St. Louis Brown Stockings    1
# Boston Rustlers              1
# Name: Tm, dtype: int64

# %%
dfnew=pd.read_csv(r'Files\baseball.csv')
df.shape
# Out:
# (2594, 24)

# %%
dfnew.dropna(how='all', inplace=True)
dfnew.shape
# Out:
# (2594, 24)

# %%
dfnew.dropna(how='any', inplace=True)
dfnew.shape
# Out:
# (422, 24)

# %%
dfnew.dropna(subset=['W','Attendance'], inplace=True)
dfnew.shape
# Out:
# (2520, 24)

# %%
dfnew2=pd.read_csv(r'Files\baseball.csv',usecols=['Tm','Playoffs','Attendance'])
dfnew2.head(10)
# Out:
#                      Tm         Playoffs Attendance
# 0  Arizona Diamondbacks              NaN  2,036,216
# 1  Arizona Diamondbacks              NaN  2,080,145
# 2  Arizona Diamondbacks              NaN  2,073,730
# 3  Arizona Diamondbacks              NaN  2,134,895
# 4  Arizona Diamondbacks              NaN  2,177,617
# 5  Arizona Diamondbacks   Lost LDS (3-2)  2,105,432
# 6  Arizona Diamondbacks              NaN  2,056,697
# 7  Arizona Diamondbacks              NaN  2,128,765
# 8  Arizona Diamondbacks              NaN  2,509,924
# 9  Arizona Diamondbacks  Lost NLCS (4-0)  2,325,249

# %%
dfnew2.fillna(0,inplace=True)
dfnew2.head(10)
dfnew2.isnull().sum()
# Out:
# Tm            0
# Playoffs      0
# Attendance    0
# dtype: int64

# %%
dfnew2=pd.read_csv(r'Files\baseball.csv',usecols=['Tm','Playoffs','Attendance'])
dfnew2.head(10)
# Out:
#                      Tm         Playoffs Attendance
# 0  Arizona Diamondbacks              NaN  2,036,216
# 1  Arizona Diamondbacks              NaN  2,080,145
# 2  Arizona Diamondbacks              NaN  2,073,730
# 3  Arizona Diamondbacks              NaN  2,134,895
# 4  Arizona Diamondbacks              NaN  2,177,617
# 5  Arizona Diamondbacks   Lost LDS (3-2)  2,105,432
# 6  Arizona Diamondbacks              NaN  2,056,697
# 7  Arizona Diamondbacks              NaN  2,128,765
# 8  Arizona Diamondbacks              NaN  2,509,924
# 9  Arizona Diamondbacks  Lost NLCS (4-0)  2,325,249

# %%
dfnew2['Playoffs'].fillna(0,inplace=True)
dfnew2.head(10)
dfnew2.isnull().sum()
# Out:
# Tm             0
# Playoffs       0
# Attendance    74
# dtype: int64

# %%
dfnew2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2594 entries, 0 to 2593
# Data columns (total 3 columns):
# Tm            2594 non-null object
# Playoffs      2594 non-null object
# Attendance    2520 non-null object
# dtypes: object(3)
# memory usage: 60.9+ KB

# %%
dfnew3=pd.read_csv(r'Files\baseball.csv',usecols=['Tm','Playoffs','Attendance'])
dfnew3.head(10)
# Out:
#                      Tm         Playoffs Attendance
# 0  Arizona Diamondbacks              NaN  2,036,216
# 1  Arizona Diamondbacks              NaN  2,080,145
# 2  Arizona Diamondbacks              NaN  2,073,730
# 3  Arizona Diamondbacks              NaN  2,134,895
# 4  Arizona Diamondbacks              NaN  2,177,617
# 5  Arizona Diamondbacks   Lost LDS (3-2)  2,105,432
# 6  Arizona Diamondbacks              NaN  2,056,697
# 7  Arizona Diamondbacks              NaN  2,128,765
# 8  Arizona Diamondbacks              NaN  2,509,924
# 9  Arizona Diamondbacks  Lost NLCS (4-0)  2,325,249

# %%
dfnew3.fillna(method='bfill',inplace=True)
dfnew3.head(10)
# Out:
#                      Tm         Playoffs Attendance
# 0  Arizona Diamondbacks   Lost LDS (3-2)  2,036,216
# 1  Arizona Diamondbacks   Lost LDS (3-2)  2,080,145
# 2  Arizona Diamondbacks   Lost LDS (3-2)  2,073,730
# 3  Arizona Diamondbacks   Lost LDS (3-2)  2,134,895
# 4  Arizona Diamondbacks   Lost LDS (3-2)  2,177,617
# 5  Arizona Diamondbacks   Lost LDS (3-2)  2,105,432
# 6  Arizona Diamondbacks  Lost NLCS (4-0)  2,056,697
# 7  Arizona Diamondbacks  Lost NLCS (4-0)  2,128,765
# 8  Arizona Diamondbacks  Lost NLCS (4-0)  2,509,924
# 9  Arizona Diamondbacks  Lost NLCS (4-0)  2,325,249

# %%
dfnew4=pd.read_csv(r'Files\baseball.csv',usecols=['Tm','Playoffs','Attendance'])
dfnew4.head(10)
# Out:
#                      Tm         Playoffs Attendance
# 0  Arizona Diamondbacks              NaN  2,036,216
# 1  Arizona Diamondbacks              NaN  2,080,145
# 2  Arizona Diamondbacks              NaN  2,073,730
# 3  Arizona Diamondbacks              NaN  2,134,895
# 4  Arizona Diamondbacks              NaN  2,177,617
# 5  Arizona Diamondbacks   Lost LDS (3-2)  2,105,432
# 6  Arizona Diamondbacks              NaN  2,056,697
# 7  Arizona Diamondbacks              NaN  2,128,765
# 8  Arizona Diamondbacks              NaN  2,509,924
# 9  Arizona Diamondbacks  Lost NLCS (4-0)  2,325,249

# %%
dfnew4.fillna(method='ffill',inplace=True)
dfnew4.head(10)
# Out:
#    Unnamed: 0  Rk  Year                    Tm       Lg    G   W   L  Ties  \
# 0           1   1  2016  Arizona Diamondbacks  NL West  162  69  93     0
# 1           2   2  2015  Arizona Diamondbacks  NL West  162  79  83     0
# 2           3   3  2014  Arizona Diamondbacks  NL West  162  64  98     0
# 3           4   4  2013  Arizona Diamondbacks  NL West  162  81  81     0
# 4           5   5  2012  Arizona Diamondbacks  NL West  162  81  81     0
# 5           6   6  2011  Arizona Diamondbacks  NL West  162  94  68     0
# 6           7   7  2010  Arizona Diamondbacks  NL West  162  65  97     0
# 7           8   8  2009  Arizona Diamondbacks  NL West  162  70  92     0
# 8           9   9  2008  Arizona Diamondbacks  NL West  162  82  80     0
# 9          10  10  2007  Arizona Diamondbacks  NL West  162  90  72     0
#
#     W.L.          ...             R   RA Attendance BatAge  PAge  X.Bat X.P  \
# 0  0.426          ...           752  890  2,036,216   26.7  26.4     50  29
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  Rk  Year                    Tm       Lg    G   W   L  Ties  \
# 0           1   1  2016  Arizona Diamondbacks  NL West  162  69  93     0
# 1           2   2  2015  Arizona Diamondbacks  NL West  162  79  83     0
# 2           3   3  2014  Arizona Diamondbacks  NL West  162  64  98     0
# 3           4   4  2013  Arizona Diamondbacks  NL West  162  81  81     0
# 4           5   5  2012  Arizona Diamondbacks  NL West  162  81  81     0
# 5           6   6  2011  Arizona Diamondbacks  NL West  162  94  68     0
# 6           7   7  2010  Arizona Diamondbacks  NL West  162  65  97     0
# 7           8   8  2009  Arizona Diamondbacks  NL West  162  70  92     0
# 8           9   9  2008  Arizona Diamondbacks  NL West  162  82  80     0
# 9          10  10  2007  Arizona Diamondbacks  NL West  162  90  72     0
#
#     W.L.          ...             R   RA Attendance BatAge  PAge  X.Bat X.P  \
# 0  0.426          ...           752  890  2,036,216   26.7  26.4     50  29
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Rk              int64
# Year            int64
# Tm             object
# Lg             object
# G               int64
# W               int64
# L               int64
# Ties            int64
# W.L.          float64
# pythW.L.      float64
# Finish         object
# GB             object
# Playoffs       object
# R               int64
# RA              int64
# Attendance     object
# BatAge        float64
# PAge          float64
# X.Bat           int64
# X.P             int64
# Top.Player     object
# Managers       object
# current        object
# dtype: object

# %%
df['Year'].astype(float).head(10)
# Out:
# 0    2016.0
# 1    2015.0
# 2    2014.0
# 3    2013.0
# 4    2012.0
# 5    2011.0
# 6    2010.0
# 7    2009.0
# 8    2008.0
# 9    2007.0
# Name: Year, dtype: float64

# %%
df
# Out:
#       Unnamed: 0  Rk  Year                    Tm       Lg    G    W    L  \
# 0              1   1  2016  Arizona Diamondbacks  NL West  162   69   93
# 1              2   2  2015  Arizona Diamondbacks  NL West  162   79   83
# 2              3   3  2014  Arizona Diamondbacks  NL West  162   64   98
# 3              4   4  2013  Arizona Diamondbacks  NL West  162   81   81
# 4              5   5  2012  Arizona Diamondbacks  NL West  162   81   81
# 5              6   6  2011  Arizona Diamondbacks  NL West  162   94   68
# 6              7   7  2010  Arizona Diamondbacks  NL West  162   65   97
# 7              8   8  2009  Arizona Diamondbacks  NL West  162   70   92
# 8              9   9  2008  Arizona Diamondbacks  NL West  162   82   80
# 9             10  10  2007  Arizona Diamondbacks  NL West  162   90   72
# 10            11  11  2006  Arizona Diamondbacks  NL West  162   76   86
# 11            12  12  2005  Arizona Diamondbacks  NL West  162   77   85
# ...

# %%
df['Year']=df['Year'].astype(float)

# %%
df
# Out:
#       Unnamed: 0  Rk    Year                    Tm       Lg    G    W    L  \
# 0              1   1  2016.0  Arizona Diamondbacks  NL West  162   69   93
# 1              2   2  2015.0  Arizona Diamondbacks  NL West  162   79   83
# 2              3   3  2014.0  Arizona Diamondbacks  NL West  162   64   98
# 3              4   4  2013.0  Arizona Diamondbacks  NL West  162   81   81
# 4              5   5  2012.0  Arizona Diamondbacks  NL West  162   81   81
# 5              6   6  2011.0  Arizona Diamondbacks  NL West  162   94   68
# 6              7   7  2010.0  Arizona Diamondbacks  NL West  162   65   97
# 7              8   8  2009.0  Arizona Diamondbacks  NL West  162   70   92
# 8              9   9  2008.0  Arizona Diamondbacks  NL West  162   82   80
# 9             10  10  2007.0  Arizona Diamondbacks  NL West  162   90   72
# 10            11  11  2006.0  Arizona Diamondbacks  NL West  162   76   86
# ...

# %%
df['W']=df['W'].astype(str)
df.head(10)
# Out:
#    Unnamed: 0  Rk    Year                    Tm       Lg    G   W   L  Ties  \
# 0           1   1  2016.0  Arizona Diamondbacks  NL West  162  69  93     0
# 1           2   2  2015.0  Arizona Diamondbacks  NL West  162  79  83     0
# 2           3   3  2014.0  Arizona Diamondbacks  NL West  162  64  98     0
# 3           4   4  2013.0  Arizona Diamondbacks  NL West  162  81  81     0
# 4           5   5  2012.0  Arizona Diamondbacks  NL West  162  81  81     0
# 5           6   6  2011.0  Arizona Diamondbacks  NL West  162  94  68     0
# 6           7   7  2010.0  Arizona Diamondbacks  NL West  162  65  97     0
# 7           8   8  2009.0  Arizona Diamondbacks  NL West  162  70  92     0
# 8           9   9  2008.0  Arizona Diamondbacks  NL West  162  82  80     0
# 9          10  10  2007.0  Arizona Diamondbacks  NL West  162  90  72     0
#
#     W.L.          ...             R   RA Attendance BatAge  PAge  X.Bat X.P  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Rk              int64
# Year          float64
# Tm             object
# Lg             object
# G               int64
# W              object
# L               int64
# Ties            int64
# W.L.          float64
# pythW.L.      float64
# Finish         object
# GB             object
# Playoffs       object
# R               int64
# RA              int64
# Attendance     object
# BatAge        float64
# PAge          float64
# X.Bat           int64
# X.P             int64
# Top.Player     object
# Managers       object
# current        object
# dtype: object

# %%
df=pd.read_csv(r'Files\baseball.csv' )
df.head()
df.sort_values(['Tm','Lg'],ascending=False, na_position="first").tail(10)
# Out:
#       Unnamed: 0  Rk  Year                    Tm       Lg    G    W   L  Ties  \
# 17            18  18  1999  Arizona Diamondbacks  NL West  162  100  62     0
# 18            19  19  1998  Arizona Diamondbacks  NL West  162   65  97     0
# 1155        1156  13  2004        Anaheim Angels  AL West  162   92  70     0
# 1156        1157  14  2003        Anaheim Angels  AL West  162   77  85     0
# 1157        1158  15  2002        Anaheim Angels  AL West  162   99  63     0
# 1158        1159  16  2001        Anaheim Angels  AL West  162   75  87     0
# 1159        1160  17  2000        Anaheim Angels  AL West  162   82  80     0
# 1160        1161  18  1999        Anaheim Angels  AL West  162   70  92     0
# 1161        1162  19  1998        Anaheim Angels  AL West  162   85  77     0
# 1162        1163  20  1997        Anaheim Angels  AL West  162   84  78     0
#
#        W.L.              ...                  R   RA Attendance BatAge  PAge  \
# ...

# %%
df=pd.read_csv(r'Files\baseball.csv' )
df.head()
df.sort_values(['Tm','Lg'],ascending=[False,True], na_position="first").head(10)
# Out:
#       Unnamed: 0  Rk  Year                   Tm  Lg    G   W    L  Ties  \
# 1460        1461  57  1960  Washington Senators  AL  154  73   81     0
# 1461        1462  58  1959  Washington Senators  AL  154  63   91     0
# 1462        1463  59  1958  Washington Senators  AL  156  61   93     2
# 1463        1464  60  1957  Washington Senators  AL  154  55   99     0
# 1464        1465  61  1956  Washington Senators  AL  155  59   95     1
# 1465        1466  62  1955  Washington Senators  AL  154  53  101     0
# 1466        1467  63  1954  Washington Senators  AL  155  66   88     1
# 1467        1468  64  1953  Washington Senators  AL  152  76   76     0
# 1468        1469  65  1952  Washington Senators  AL  157  78   76     3
# 1469        1470  66  1951  Washington Senators  AL  154  62   92     0
#
#        W.L.       ...           R   RA Attendance BatAge  PAge  X.Bat X.P  \
# 1460  0.474       ...         672  696    743,404   27.3  26.8     37  18
# ...
