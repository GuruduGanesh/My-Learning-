# %%
import pandas as pd
df=pd.read_csv(r'Files\transit-segments.csv')
df.head()
# Out:
#    mmsi               name  transit  segment  seg_length  avg_sog  min_sog  \
# 0     1        Us Govt Ves        1        1         5.1     13.2      9.2
# 1     1  Dredge Capt Frank        1        1        13.5     18.6     10.4
# 2     1      Us Gov Vessel        1        1         4.3     16.2     10.3
# 3     1      Us Gov Vessel        2        1         9.2     15.4     14.5
# 4     1  Dredge Capt Frank        2        1         9.2     15.4     14.6
#
#    max_sog  pdgt10        st_time       end_time
# 0     14.5    96.5  2/10/09 16:03  2/10/09 16:27
# 1     20.6   100.0   4/6/09 14:31   4/6/09 15:20
# 2     20.5   100.0   4/6/09 14:36   4/6/09 14:55
# 3     16.1   100.0  4/10/09 17:58  4/10/09 18:34
# 4     16.2   100.0  4/10/09 17:59  4/10/09 18:35

# %%
df.dtypes
# Out:
# mmsi            int64
# name           object
# transit         int64
# segment         int64
# seg_length    float64
# avg_sog       float64
# min_sog       float64
# max_sog       float64
# pdgt10        float64
# st_time        object
# end_time       object
# dtype: object

# %%
df2=pd.read_csv(r'Files\transit-segments.csv', parse_dates=['st_time'])
df2.head(10)
# Out:
#    mmsi               name  transit  segment  seg_length  avg_sog  min_sog  \
# 0     1        Us Govt Ves        1        1         5.1     13.2      9.2
# 1     1  Dredge Capt Frank        1        1        13.5     18.6     10.4
# 2     1      Us Gov Vessel        1        1         4.3     16.2     10.3
# 3     1      Us Gov Vessel        2        1         9.2     15.4     14.5
# 4     1  Dredge Capt Frank        2        1         9.2     15.4     14.6
# 5     1  Bil Holman Dredge        1        1        17.4     34.3     33.9
# 6     1  Bil Holman Dredge        1        2        76.0     34.4     33.8
# 7     1         S.d. Gumel        1        1        13.7      6.9      3.0
# 8     9         Shearwater        4        1        11.6      8.8      7.9
# 9     9         Shearwater        8        1        11.6      8.3      7.4
#
#    max_sog  pdgt10             st_time       end_time
# 0     14.5    96.5 2009-02-10 16:03:00  2/10/09 16:27
# ...

# %%
df2.dtypes
# Out:
# mmsi                   int64
# name                  object
# transit                int64
# segment                int64
# seg_length           float64
# avg_sog              float64
# min_sog              float64
# max_sog              float64
# pdgt10               float64
# st_time       datetime64[ns]
# end_time              object
# dtype: object

# %%
df2.end_time=pd.to_datetime(df2.end_time)

# %%
df2.dtypes
# Out:
# mmsi                   int64
# name                  object
# transit                int64
# segment                int64
# seg_length           float64
# avg_sog              float64
# min_sog              float64
# max_sog              float64
# pdgt10               float64
# st_time       datetime64[ns]
# end_time      datetime64[ns]
# dtype: object

# %%
df2.head(10)
# Out:
#    mmsi               name  transit  segment  seg_length  avg_sog  min_sog  \
# 0     1        Us Govt Ves        1        1         5.1     13.2      9.2
# 1     1  Dredge Capt Frank        1        1        13.5     18.6     10.4
# 2     1      Us Gov Vessel        1        1         4.3     16.2     10.3
# 3     1      Us Gov Vessel        2        1         9.2     15.4     14.5
# 4     1  Dredge Capt Frank        2        1         9.2     15.4     14.6
# 5     1  Bil Holman Dredge        1        1        17.4     34.3     33.9
# 6     1  Bil Holman Dredge        1        2        76.0     34.4     33.8
# 7     1         S.d. Gumel        1        1        13.7      6.9      3.0
# 8     9         Shearwater        4        1        11.6      8.8      7.9
# 9     9         Shearwater        8        1        11.6      8.3      7.4
#
#    max_sog  pdgt10             st_time            end_time
# 0     14.5    96.5 2009-02-10 16:03:00 2009-02-10 16:27:00
# ...

# %%
df2[df2['min_sog'].between(10.0,20.0)].head()
# Out:
#     mmsi               name  transit  segment  seg_length  avg_sog  min_sog  \
# 1      1  Dredge Capt Frank        1        1        13.5     18.6     10.4
# 2      1      Us Gov Vessel        1        1         4.3     16.2     10.3
# 3      1      Us Gov Vessel        2        1         9.2     15.4     14.5
# 4      1  Dredge Capt Frank        2        1         9.2     15.4     14.6
# 17    21      Us Gov Vessel        3        1        15.1     13.7     10.0
#
#     max_sog  pdgt10             st_time            end_time
# 1      20.6   100.0 2009-04-06 14:31:00 2009-04-06 15:20:00
# 2      20.5   100.0 2009-04-06 14:36:00 2009-04-06 14:55:00
# 3      16.1   100.0 2009-04-10 17:58:00 2009-04-10 18:34:00
# 4      16.2   100.0 2009-04-10 17:59:00 2009-04-10 18:35:00
# 17     15.1    91.8 2011-03-18 11:18:00 2011-03-18 12:26:00

# %%
df2[df2['st_time'].between("2011-01-01","2011-12-13")].head(10)
# Out:
#     mmsi           name  transit  segment  seg_length  avg_sog  min_sog  \
# 7      1     S.d. Gumel        1        1        13.7      6.9      3.0
# 16    21  Us Gov Vessel        2        1        48.7      6.6      3.4
# 17    21  Us Gov Vessel        3        1        15.1     13.7     10.0
# 18    21  Us Gov Vessel        4        1        18.0      9.7      4.6
# 19    21  Us Gov Vessel        5        1        11.2     12.9      6.1
# 20    21  Us Gov Vessel        6        1         5.8     16.5     15.1
# 21    21  Us Gov Vessel        7        1         7.6     10.0      8.8
# 22    21  Us Gov Vessel        8        1        11.1     10.4      8.8
# 23    21  Us Gov Vessel        9        1         9.8     13.4      5.8
# 24    21  Us Gov Vessel       10        1        15.9     15.8     15.4
#
#     max_sog  pdgt10             st_time            end_time
# 7      14.0    38.2 2011-05-04 11:28:00 2011-05-04 13:30:00
# ...

# %%
df3=df2
df3.drop_duplicate(subset=['name'],keep=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-b99b7efff431> in <module>()
#       1 df3=df2
# ----> 2 df3.drop_duplicate(subset=['name'],keep=False)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'drop_duplicate'

# %%
df2['name'].unique()
# Out:
# array(['Us Govt Ves', 'Dredge Capt Frank', 'Us Gov Vessel', ...,
#        'Ct Pilot', 'Earl Jones', 'Oi'], dtype=object)

# %%
df2['segment'].nunique()
# Out:
# 88

# %%
df2['segment'].unique()
# Out:
# array([  1,   2,   3,   5,   6,   7,  17,  21,  19,  20,  28,  10,  14,
#         16,  26,  12,  22,  24,  32,  40,  44,  13,  62,  42,  54,   4,
#          9,  27,  15,  45,  25,  49,  53,  57,  29,  33,  59,  63,  71,
#         23,  77,  85,  92,  95,   8,  97, 106, 119,  11,  68, 137, 146,
#        157,  74, 170,  79,  34,  18,  36,  38,  61,  64,  65, 233, 245,
#        161, 165, 166, 162, 200, 207, 189, 190, 208,  35,  41,  37,  43,
#         46,  48,  60,  67,  69,  30,  31,  39,  50,  51], dtype=int64)
